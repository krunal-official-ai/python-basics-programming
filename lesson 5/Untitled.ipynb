# %%
class india:
    def X (self):
        print("Jai hind")
        
class pakistan(india):
    def X (self):
        super().X()
        print("Ok")

d = pakistan()
d.X()
# Out:
# Jai hind
# Ok

# %%
X = [1,2,3,4,5,8,9,10]
# print(max(X))
max_val = 0

for num in X:
    if num > max_val:
        max_val = num
print(max_val)
# Out:
# 10
